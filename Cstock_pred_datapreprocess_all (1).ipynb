# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_path="/content/drive/MyDrive/stock-prediction/"
dataset=os.listdir(dataset_path)

# %%
string=""

string = string + dataset[10]
print(string)
print(dataset_path)
# Out:
# merged_data.csv
# /content/drive/MyDrive/stock-prediction/

# %%
dataset=pd.read_csv(dataset_path + string)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,7,8,9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1   SYMBOL_CODE  ... day month  year
# 0           0             0  EGS30221C013  ...   2     1  2018
# 1           1             1  EGS37091C013  ...   2     1  2018
# 2           2             2  EGS38081C013  ...   2     1  2018
# 3           3             3  EGS380G1C011  ...   2     1  2018
# 4           4             4  EGS380P1C010  ...   2     1  2018
# 5           5             5  EGS380S1C017  ...   2     1  2018
# 6           6             6  EGS38161C013  ...   2     1  2018
# 7           7             7  EGS38191C010  ...   2     1  2018
# 8           8             8  EGS38201C017  ...   2     1  2018
# 9           9             9  EGS38211C016  ...   2     1  2018
#
# [10 rows x 16 columns]

# %%
dataset=dataset.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)

# %%
dataset.shape
# Out:
# (154632, 14)

# %%
dataset.isna().sum()
# Out:
# SYMBOL_CODE     0
# ENG_NAME        0
# REUTERS         0
# TRADE_DATE      0
# TRADE_VALUE     0
# TRADE_VOLUME    0
# TRADE_COUNT     0
# OPEN_PRICE      0
# HIGH_PRICE      0
# LOW_PRICE       0
# CLOSE_PRICE     0
# day             0
# month           0
# year            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154632 entries, 0 to 154631
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SYMBOL_CODE   154632 non-null  object
#  1   ENG_NAME      154632 non-null  object
#  2   REUTERS       154632 non-null  object
#  3   TRADE_DATE    154632 non-null  object
#  4   TRADE_VALUE   154632 non-null  object
#  5   TRADE_VOLUME  154632 non-null  object
#  6   TRADE_COUNT   154632 non-null  object
#  7   OPEN_PRICE    154632 non-null  object
#  8   HIGH_PRICE    154632 non-null  object
#  9   LOW_PRICE     154632 non-null  object
#  10  CLOSE_PRICE   154632 non-null  object
#  11  day           154632 non-null  int64
#  12  month         154632 non-null  int64
#  13  year          154632 non-null  int64
# dtypes: int64(3), object(11)
# memory usage: 16.5+ MB

# %%
VAL=['TRADE_VALUE','TRADE_VOLUME','TRADE_COUNT','OPEN_PRICE','HIGH_PRICE','LOW_PRICE','CLOSE_PRICE']
for i in VAL:
  print(dataset[i])
  dataset[i] =dataset[i].astype(str).str.replace(",", "").astype(float)
# Out:
# 0                 104
# 1         1.36817e+06
# 2               80211
# 3               78000
# 4         1.74122e+07
#              ...
# 154627    2,25,86,354
# 154628       1,59,834
# 154629       3,20,336
# 154630         23,952
# 154631       9,11,451
# Name: TRADE_VALUE, Length: 154632, dtype: object
# 0                10
# 1              3056
# 2               537
# 3              1000
# 4           1260791
#             ...
# 154627    22,85,013
# 154628        3,876
# 154629        7,525
# 154630          879
# 154631     3,80,772
# Name: TRADE_VOLUME, Length: 154632, dtype: object
# 0           1
# 1           9
# 2           3
# 3           1
# 4         624
#          ...
# 154627    966
# 154628     12
# 154629     18
# 154630      2
# 154631    152
# Name: TRADE_COUNT, Length: 154632, dtype: object
# 0          10.4
# 1         469.8
# 2           153
# 3            78
# 4         13.87
#           ...
# 154627    10.35
# 154628    41.05
# 154629        7
# 154630    27.01
# 154631     2.52
# Name: OPEN_PRICE, Length: 154632, dtype: object
# 0          10.4
# 1         469.8
# 2           153
# 3            78
# 4         14.05
#           ...
# 154627    10.35
# 154628    41.26
# 154629        7
# 154630     27.5
# 154631     2.52
# Name: HIGH_PRICE, Length: 154632, dtype: object
# 0          10.4
# 1           430
# 2           140
# 3            78
# 4         13.65
#           ...
# 154627      9.6
# 154628    41.05
# 154629     6.84
# 154630    27.01
# 154631     2.35
# Name: LOW_PRICE, Length: 154632, dtype: object
# 0            9.5
# 1          447.7
# 2         149.37
# 3             78
# 4          13.81
#            ...
# 154627      9.88
# 154628     41.24
# 154629       6.9
# 154630     27.25
# 154631      2.39
# Name: CLOSE_PRICE, Length: 154632, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154632 entries, 0 to 154631
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SYMBOL_CODE   154632 non-null  object
#  1   ENG_NAME      154632 non-null  object
#  2   REUTERS       154632 non-null  object
#  3   TRADE_DATE    154632 non-null  object
#  4   TRADE_VALUE   154632 non-null  float64
#  5   TRADE_VOLUME  154632 non-null  float64
#  6   TRADE_COUNT   154632 non-null  float64
#  7   OPEN_PRICE    154632 non-null  float64
#  8   HIGH_PRICE    154632 non-null  float64
#  9   LOW_PRICE     154632 non-null  float64
#  10  CLOSE_PRICE   154632 non-null  float64
#  11  day           154632 non-null  int64
#  12  month         154632 non-null  int64
#  13  year          154632 non-null  int64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 16.5+ MB

# %%
dataset.describe()
# Out:
#         TRADE_VALUE  TRADE_VOLUME  ...          month           year
# count  1.546320e+05  1.546320e+05  ...  154632.000000  154632.000000
# mean   3.612162e+06  8.759448e+05  ...       6.846532    2015.600775
# std    1.554095e+07  4.985450e+06  ...       3.398511       3.430384
# min    1.000000e+00  1.000000e+00  ...       1.000000    2011.000000
# 25%    5.792500e+04  5.250000e+03  ...       4.000000    2012.000000
# 50%    3.328040e+05  4.345250e+04  ...       7.000000    2018.000000
# 75%    1.737422e+06  2.889812e+05  ...      10.000000    2019.000000
# max    1.490838e+09  2.680535e+08  ...      12.000000    2019.000000
#
# [8 rows x 10 columns]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(15.7,11.27)})
cols=["SYMBOL_CODE","ENG_NAME","REUTERS","TRADE_DATE","TRADE_VALUE","TRADE_VOLUME","TRADE_COUNT","OPEN_PRICE","HIGH_PRICE","LOW_PRICE","CLOSE_PRICE"]

selected_columns = dataset[["TRADE_VALUE","TRADE_VOLUME","TRADE_DATE","TRADE_COUNT","OPEN_PRICE","HIGH_PRICE","LOW_PRICE","CLOSE_PRICE"]]
new_df = selected_columns.copy()
box_dataset=new_df
ax = sns.boxplot(data=box_dataset, orient="h", palette="Set2")

# %%
print(dataset['ENG_NAME'].value_counts())
# Out:
# Egyptian Transport (EGYTRANS)                                 873
# Alexandria Mineral Oils Company                               873
# Cairo Poultry                                                 873
# Asek Company for Mining    - Ascom                            873
# Egyptian Kuwaiti Holding                                      873
#                                                              ...
# El Taamir Securitization The Seconed Issue Tran D Jul 2022      1
# El Taamir Securitization The Seconed Issue Tran H Jul 2024      1
# El Taamir Securitization The Seconed Issue Tran A Jan 2020      1
# El Taamir Securitization The Seconed Issue Tran C Jul 2020      1
# El Taamir Securitization The Seconed Issue Tran B Apr 2020      1
# Name: ENG_NAME, Length: 270, dtype: int64

# %%
print(dataset['REUTERS'].value_counts())
# Out:
# AMER.CA                 873
# COMI.CA                 873
# AMOC.CA                 873
# EHDR.CA                 873
# EKHO.CA                 873
#                        ...
# EGETSC02B=CA              1
# EGETSC02A=CA              1
# EGETSC02D=CA              1
# EGETSC02H=CA              1
# EGETSC02C=CA              1
# Name: REUTERS, Length: 268, dtype: int64

# %%
pd.crosstab(dataset['ENG_NAME'],dataset['REUTERS'])
# Out:
# REUTERS                                    AALR.CA               ...  ZMID.CA
# ENG_NAME                                                         ...
# AJWA for Food Industries company    Egypt                     0  ...                     0
# ARAB POLVARA SPINNING & WEAVING CO.                           0  ...                     0
# Abou Kir Fertilizers                                          0  ...                     0
# Abu Dhabi Islamic Bank- Egypt                                 0  ...                     0
# Acrow Misr                                                    0  ...                     0
# ...                                                         ...  ...                   ...
# Univert Food Industries                                       0  ...                     0
# Upper Egypt Flour Mills                                       0  ...                     0
# Vertika for Industry & Trade                                  0  ...                     0
# Wadi Kom Ombo Land Reclamation                                0  ...                     0
# Zahraa Maadi Investment & Development                         0  ...                   794
#
# [270 rows x 268 columns]

# %%
df1=dataset

# %%
def replace(group):   
    mean, std = group.mean(), group.std()
    outliers = (group - mean).abs() > 2*std

    group[outliers] = mean
    return group
cols=['TRADE_VALUE','TRADE_VOLUME','TRADE_COUNT','OPEN_PRICE','HIGH_PRICE','LOW_PRICE','CLOSE_PRICE']
for i in cols:

   df1[i]=replace(df1[i])
# df1=df1.groupby('REUTERS').transform(replace)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1.head(10)
# Out:
#     SYMBOL_CODE                                           ENG_NAME  ... month  year
# 0  EGS30221C013     The Arab Dairy Products Co. Arab Dairy - Panda  ...     1  2018
# 1  EGS37091C013                                    Eastern Company  ...     1  2018
# 2  EGS38081C013    Egyptian International Pharmaceuticals (EIPICO)  ...     1  2018
# 3  EGS380G1C011                          Minapharm Pharmaceuticals  ...     1  2018
# 4  EGS380P1C010                    Alexandria Mineral Oils Company  ...     1  2018
# 5  EGS380S1C017                          Sidi Kerir Petrochemicals  ...     1  2018
# 6  EGS38161C013  Universal For Paper and Packaging Materials (U...  ...     1  2018
# 7  EGS38191C010                               Abou Kir Fertilizers  ...     1  2018
# 8  EGS38201C017                Egyptian Chemical Industries (Kima)  ...     1  2018
# 9  EGS38211C016                           Misr Chemical Industries  ...     1  2018
#
# [10 rows x 14 columns]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(15.7,11.27)})
cols=["SYMBOL_CODE","ENG_NAME","REUTERS","TRADE_DATE","TRADE_VALUE","TRADE_VOLUME","TRADE_COUNT","OPEN_PRICE","HIGH_PRICE","LOW_PRICE","CLOSE_PRICE"]

selected_columns = df1[["TRADE_VALUE","TRADE_VOLUME","TRADE_COUNT","OPEN_PRICE","HIGH_PRICE","LOW_PRICE","CLOSE_PRICE"]]
new_df = selected_columns.copy()
box_dataset=new_df
ax = sns.boxplot(data=box_dataset, orient="h", palette="Set2")

# %%
dataset.shape
# Out:
# (154632, 14)

# %%
df1.shape
# Out:
# (154632, 14)

# %%
data2=df1

# %%
data2.head(10)
# Out:
#     SYMBOL_CODE                                           ENG_NAME  ... month  year
# 0  EGS30221C013     The Arab Dairy Products Co. Arab Dairy - Panda  ...     1  2018
# 1  EGS37091C013                                    Eastern Company  ...     1  2018
# 2  EGS38081C013    Egyptian International Pharmaceuticals (EIPICO)  ...     1  2018
# 3  EGS380G1C011                          Minapharm Pharmaceuticals  ...     1  2018
# 4  EGS380P1C010                    Alexandria Mineral Oils Company  ...     1  2018
# 5  EGS380S1C017                          Sidi Kerir Petrochemicals  ...     1  2018
# 6  EGS38161C013  Universal For Paper and Packaging Materials (U...  ...     1  2018
# 7  EGS38191C010                               Abou Kir Fertilizers  ...     1  2018
# 8  EGS38201C017                Egyptian Chemical Industries (Kima)  ...     1  2018
# 9  EGS38211C016                           Misr Chemical Industries  ...     1  2018
#
# [10 rows x 14 columns]

# %%
dataset=df1

# %%
data2=df1

# %%
dataset.set_index('TRADE_DATE', inplace=True)

# %%
 dataset=dataset.sort_index()

# %%
dataset = dataset.drop_duplicates()
print(dataset)
# Out:
#          SYMBOL_CODE  ...  year
# 0       EGS30221C013  ...  2018
# 1       EGS37091C013  ...  2018
# 2       EGS38081C013  ...  2018
# 3       EGS380G1C011  ...  2018
# 4       EGS380P1C010  ...  2018
# ...              ...  ...   ...
# 154627  EGS3C251C013  ...  2012
# 154628  EGS60321C014  ...  2012
# 154629  EGS60322C012  ...  2012
# 154630  EGS673T1C012  ...  2012
# 154631  EGS46051C016  ...  2012
#
# [154444 rows x 14 columns]

# %%
dataset.reset_index(inplace=True)
print('Number of entries within the input dataframe : ',len(dataset))

print('Numbr of unique time entries in input dataframe: ',len(pd.unique(dataset['TRADE_DATE'])))
# Out:
# Number of entries within the input dataframe :  154444
# Numbr of unique time entries in input dataframe:  873

# %%
dataset.tail(10)
# Out:
#          index   SYMBOL_CODE  ... month  year
# 154434  154622  EGS3G231C011  ...    12  2012
# 154435  154623  EGS21531C016  ...    12  2012
# 154436  154624  EGS3F021C017  ...    12  2012
# 154437  154625  EGS60241C014  ...    12  2012
# 154438  154626  EGS38251C012  ...    12  2012
# 154439  154627  EGS3C251C013  ...    12  2012
# 154440  154628  EGS60321C014  ...    12  2012
# 154441  154629  EGS60322C012  ...    12  2012
# 154442  154630  EGS673T1C012  ...    12  2012
# 154443  154631  EGS46051C016  ...    12  2012
#
# [10 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
dataset.CLOSE_PRICE.plot(figsize=(40,20))
plt.show()

# %%
def correlation(data):
  
  corr=data.corr()
  sns.heatmap(corr,annot=True)
  plt.show()

# %%
correlation(dataset)

# %% [markdown]
# DESCRIPTIVE STATISTICS

# %%
dataset.describe()
# Out:
#                index   TRADE_VALUE  ...          month           year
# count  154444.000000  1.544440e+05  ...  154444.000000  154444.000000
# mean    77301.240806  2.143692e+06  ...       6.840259    2015.596637
# std     44663.844356  4.740528e+06  ...       3.395816       3.430419
# min         0.000000  1.000000e+00  ...       1.000000    2011.000000
# 25%     38610.750000  5.797035e+04  ...       4.000000    2012.000000
# 50%     77221.500000  3.329085e+05  ...       7.000000    2018.000000
# 75%    116020.250000  1.737774e+06  ...      10.000000    2019.000000
# max    154631.000000  3.468463e+07  ...      12.000000    2019.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# BASIC FEATURE ENGINEERING

# %%
dataset=dataset.drop(["day","month","year"],axis=1)

# %%
dataset=dataset.drop(['ENG_NAME'],axis=1)

# %%
selected_columns = dataset[["CLOSE_PRICE","LOW_PRICE","HIGH_PRICE","OPEN_PRICE","TRADE_COUNT","TRADE_VOLUME","TRADE_VALUE","REUTERS","SYMBOL_CODE"]]
new_df = selected_columns.copy()
dataset=new_df

# %%
dataset.head(10)
# Out:
#    CLOSE_PRICE  LOW_PRICE  ...               REUTERS   SYMBOL_CODE
# 0     9.500000   10.40000  ...  ADPC.CA               EGS30221C013
# 1    20.669128   20.34495  ...  EAST.CA               EGS37091C013
# 2    20.669128  140.00000  ...  PHAR.CA               EGS38081C013
# 3    78.000000   78.00000  ...  MIPH.CA               EGS380G1C011
# 4    13.810000   13.65000  ...  AMOC.CA               EGS380P1C010
# 5    25.100000   24.70000  ...  SKPC.CA               EGS380S1C017
# 6    33.450000   32.00000  ...  UNIP.CA               EGS38161C013
# 7    21.750000   21.42000  ...  ABUK.CA               EGS38191C010
# 8     7.760000    7.65000  ...  EGCH.CA               EGS38201C017
# 9    15.590000   15.41000  ...  MICH.CA               EGS38211C016
#
# [10 rows x 9 columns]

# %%
correlation(dataset)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
dataset.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d47d8e490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d47d95290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d479dd510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4798fb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d47953250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4768a8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d4763efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d476025d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4d47602610>]],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset['SYMBOL_CODE']= encoder.fit_transform(dataset['SYMBOL_CODE']) 
# dataset['ENG_NAME']= encoder.fit_transform(dataset['ENG_NAME']) 
dataset['REUTERS']= encoder.fit_transform(dataset['REUTERS'])

# %%
data2=dataset

# %% [markdown]
# LINEAR REGRESSION

# %%
x=dataset.drop(['CLOSE_PRICE'],axis=1)
y=dataset['CLOSE_PRICE']

# %%
from sklearn.model_selection import KFold, cross_val_score, train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, shuffle=True)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
reg_pred=model.predict(X_test)
r_sq = model.score(X_test,y_test)

print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.9862532381587523

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':reg_pred})

# %%
act_pred=df.plot('Actual', 'Predicted', kind='scatter')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test,reg_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 2.326

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

r_f = RandomForestRegressor(max_depth=12, random_state=0)
r_f.fit(X_train, y_train)
reg_pred=r_f.predict(X_test)
r_sq = r_f.score(X_test,y_test)

print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.9902594455022989

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':reg_pred})
df
# Out:
#         Actual  Predicted
# 111599   13.59  13.576882
# 80905    40.75  39.940838
# 63645     0.82   0.814559
# 54130     8.11   8.085865
# 35623    10.49  10.503133
# ...        ...        ...
# 122535   23.86  23.779274
# 24349    44.00  43.708736
# 43974     8.70   8.727136
# 47908     8.56   8.647658
# 32016     0.44   0.452085
#
# [30889 rows x 2 columns]

# %%
act_pred=df.plot('Actual', 'Predicted', kind='scatter')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
rmse = sqrt(mean_squared_error(y_test,reg_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1.958

# %% [markdown]
# LSTM

# %%
dataset.head(10)
# Out:
#    CLOSE_PRICE  LOW_PRICE  HIGH_PRICE  ...  TRADE_VALUE  REUTERS  SYMBOL_CODE
# 0     9.500000   10.40000   10.400000  ...       104.00        8           33
# 1    20.669128   20.34495   20.937952  ...   1368169.21       72           62
# 2    20.669128  140.00000   20.937952  ...     80211.00      207           64
# 3    78.000000   78.00000   78.000000  ...     78000.00      166           65
# 4    13.810000   13.65000   14.050000  ...  17412181.44       26           66
# 5    25.100000   24.70000   25.500000  ...   8478833.94      238           68
# 6    33.450000   32.00000   34.000000  ...     10829.90      258           69
# 7    21.750000   21.42000   22.170000  ...   6239458.10        2           71
# 8     7.760000    7.65000    7.950000  ...  13152230.45       84           73
# 9    15.590000   15.41000   15.890000  ...   2858224.49      164           74
#
# [10 rows x 9 columns]

# %%
dataset.shape
# Out:
# (154444, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154632 entries, 2011-05-24 to 2019-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   CLOSE_PRICE   154632 non-null  float64
#  1   LOW_PRICE     154632 non-null  float64
#  2   HIGH_PRICE    154632 non-null  float64
#  3   OPEN_PRICE    154632 non-null  float64
#  4   TRADE_COUNT   154632 non-null  float64
#  5   TRADE_VOLUME  154632 non-null  float64
#  6   TRADE_VALUE   154632 non-null  float64
#  7   REUTERS       154632 non-null  int64
#  8   ENG_NAME      154632 non-null  int64
#  9   SYMBOL_CODE   154632 non-null  int64
# dtypes: float64(7), int64(3)
# memory usage: 13.0+ MB

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
values = dataset.values
values = values.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
scaled
# Out:
# array([[7.6993078e-04, 7.8086177e-04, 7.6145644e-04, ..., 9.4382024e-01,
#         9.5910782e-01, 9.8863637e-01],
#        [4.6055853e-02, 4.5928869e-02, 4.5825832e-02, ..., 9.5880151e-01,
#         9.6654272e-01, 5.7196969e-01],
#        [5.8094771e-03, 5.7499823e-03, 5.8839815e-03, ..., 9.4756556e-01,
#         9.7397768e-01, 5.0757575e-01],
#        ...,
#        [6.5969062e-01, 6.6699791e-01, 6.5734458e-01, ..., 9.5131087e-01,
#         9.8884755e-01, 1.5909091e-01],
#        [4.7035765e-02, 4.7206644e-02, 4.7348745e-02, ..., 3.8576779e-01,
#         4.1635686e-01, 9.1287881e-01],
#        [3.1497166e-02, 3.0240647e-02, 3.3573303e-02, ..., 8.1647938e-01,
#         8.2899630e-01, 9.6590912e-01]], dtype=float32)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
  n_vars = 1 if type(data) is list else data.shape[1]
  df = DataFrame(data)
  cols, names = list(), list()
  for i in range(n_in, 0, -1):
    cols.append(df.shift(i))
    names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
  for i in range(0, n_out):
    cols.append(df.shift(-i))
    if i == 0:
      names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
    else:
      names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
  agg = concat(cols, axis=1)
  agg.columns = names
	# drop rows with NaN values
  if dropnan:
    agg.dropna(inplace=True)
  return agg

# %%
reframed = series_to_supervised(scaled, 1, 1)

# %%
reframed.head(10)
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)  ...   var7(t)   var8(t)   var9(t)
# 1    0.000770   0.000781   0.000761  ...  0.001775  0.958802  0.571970
# 2    0.046056   0.045929   0.045826  ...  0.052002  0.947566  0.507576
# 3    0.005809   0.005750   0.005884  ...  0.143119  0.970037  0.632576
# 4    0.030167   0.030241   0.030043  ...  0.073312  0.966292  0.261364
# 5    0.089102   0.088450   0.089713  ...  0.006826  0.951311  0.159091
# 6    0.438371   0.443458   0.434792  ...  0.016384  1.000000  0.060606
# 7    0.440750   0.441755   0.442752  ...  0.025663  0.621723  0.246212
# 8    0.425282   0.425712   0.430292  ...  0.064523  0.584270  0.393939
# 9    0.491216   0.496628   0.490378  ...  0.000463  0.588015  0.397727
# 10   0.725695   0.732306   0.724491  ...  0.016449  0.614232  0.280303
#
# [10 rows x 18 columns]

# %%
reframed=reframed.iloc[: , :10]
reframed.head(10)
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)  ...  var8(t-1)  var9(t-1)   var1(t)
# 1    0.066214   0.073543   0.071715  ...   0.029963   0.125000  0.144391
# 2    0.144391   0.144140   0.144663  ...   0.269663   0.234848  0.144391
# 3    0.144391   0.993540   0.144663  ...   0.775281   0.242424  0.545671
# 4    0.545671   0.553418   0.539665  ...   0.621723   0.246212  0.096381
# 5    0.096381   0.096614   0.096982  ...   0.097378   0.250000  0.175404
# 6    0.175404   0.175055   0.176243  ...   0.891386   0.257576  0.233849
# 7    0.233849   0.226876   0.235082  ...   0.966292   0.261364  0.151956
# 8    0.151956   0.151771   0.153191  ...   0.007491   0.268939  0.054035
# 9    0.054035   0.054021   0.054756  ...   0.314607   0.276515  0.108840
# 10   0.108840   0.109108   0.109719  ...   0.614232   0.280303  0.013159
#
# [10 rows x 10 columns]

# %%
values = reframed.values
#1154

train = values[:123555, :]
validation = values[123555:139999, :]
test=values[139999:,:]
print(values.shape)
# Out:
# (154443, 10)

# %%
dataset.shape
# Out:
# (154444, 9)

# %%
train_X, train_y = train[:, :-1], train[:, -1]
validation_X, validation_y = validation[:, :-1], validation[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
validation_X = validation_X.reshape((validation_X.shape[0], 1, validation_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape,validation_X.shape, validation_y.shape)
# Out:
# (123555, 1, 9) (123555,) (14444, 1, 9) (14444,) (16444, 1, 9) (16444,)

# %%
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
model = Sequential()
model.add(LSTM(200,input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

history = model.fit(train_X, train_y, epochs=20, batch_size=150, validation_data=(validation_X, validation_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/20
# 824/824 - 8s - loss: 0.0601 - val_loss: 0.0777
# Epoch 2/20
# 824/824 - 5s - loss: 0.0621 - val_loss: 0.0781
# Epoch 3/20
# 824/824 - 5s - loss: 0.0611 - val_loss: 0.0778
# Epoch 4/20
# 824/824 - 5s - loss: 0.0615 - val_loss: 0.0777
# Epoch 5/20
# 824/824 - 5s - loss: 0.0613 - val_loss: 0.0777
# Epoch 6/20
# 824/824 - 5s - loss: 0.0615 - val_loss: 0.0776
# Epoch 7/20
# 824/824 - 5s - loss: 0.0610 - val_loss: 0.0779
# Epoch 8/20
# 824/824 - 5s - loss: 0.0607 - val_loss: 0.0779
# Epoch 9/20
# 824/824 - 5s - loss: 0.0611 - val_loss: 0.0778
# Epoch 10/20
# 824/824 - 5s - loss: 0.0605 - val_loss: 0.0776
# Epoch 11/20
# 824/824 - 5s - loss: 0.0608 - val_loss: 0.0778
# Epoch 12/20
# 824/824 - 5s - loss: 0.0606 - val_loss: 0.0776
# Epoch 13/20
# 824/824 - 5s - loss: 0.0606 - val_loss: 0.0775
# Epoch 14/20
# 824/824 - 5s - loss: 0.0605 - val_loss: 0.0775
# Epoch 15/20
# 824/824 - 5s - loss: 0.0605 - val_loss: 0.0774
# Epoch 16/20
# 824/824 - 5s - loss: 0.0607 - val_loss: 0.0776
# Epoch 17/20
# 824/824 - 5s - loss: 0.0609 - val_loss: 0.0774
# Epoch 18/20
# 824/824 - 5s - loss: 0.0605 - val_loss: 0.0774
# Epoch 19/20
# 824/824 - 5s - loss: 0.0608 - val_loss: 0.0774
# Epoch 20/20
# 824/824 - 5s - loss: 0.0611 - val_loss: 0.0774

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from keras.layers import concatenate
from math import sqrt
from sklearn.metrics import mean_absolute_error
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
test_X.shape
# Out:
# (14444, 9)

# %%
train_X.shape
# Out:
# (123555, 1, 9)

# %%
df = pd.DataFrame({'actual':inv_y, 'predicted':inv_yhat})

# %%
df.head(10)
# Out:
#       actual  predicted
# 0  30.339999   9.695509
# 1   5.190000  13.213307
# 2  22.249999  10.551853
# 3   2.690000  14.971974
# 4  46.700001  10.140093
# 5  19.010001  15.025510
# 6  17.840000  12.925106
# 7   8.760000   9.537101
# 8   3.650000   9.466036
# 9   7.310000  12.401473

# %%
act_pred=df.plot('actual', 'predicted', kind='scatter')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('mae',mean_absolute_error(inv_y,inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# mae 11.840741858232265
# Test RMSE: 20.314

# %%
import seaborn as sns
sns.boxplot(x=dataset['TRADE_VALUE'])

# %%
sns.pairplot(dataset)

# %%
corr=dataset.corr()
corr
# Out:
#               TRADE_VALUE  TRADE_VOLUME  TRADE_COUNT  ...    day  month   year
# TRADE_VALUE         1.000         0.401        0.598  ...  0.005 -0.046  0.070
# TRADE_VOLUME        0.401         1.000        0.524  ...  0.004 -0.029  0.036
# TRADE_COUNT         0.598         0.524        1.000  ...  0.000 -0.038 -0.045
# OPEN_PRICE          0.050        -0.048       -0.053  ... -0.002 -0.023 -0.016
# HIGH_PRICE          0.050        -0.048       -0.052  ... -0.002 -0.023 -0.017
# LOW_PRICE           0.049        -0.048       -0.054  ... -0.002 -0.023 -0.016
# CLOSE_PRICE         0.049        -0.048       -0.053  ... -0.002 -0.023 -0.016
# day                 0.005         0.004        0.000  ...  1.000 -0.022  0.002
# month              -0.046        -0.029       -0.038  ... -0.022  1.000 -0.134
# year                0.070         0.036       -0.045  ...  0.002 -0.134  1.000
#
# [10 rows x 10 columns]

# %% [markdown]
# XGBoost

# %%
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')

# %%
x=dataset.drop(['CLOSE_PRICE'],axis=1)
y=dataset['CLOSE_PRICE']

# %%
x.head(10)
# Out:
#    LOW_PRICE  HIGH_PRICE  OPEN_PRICE  ...  TRADE_VALUE  REUTERS  SYMBOL_CODE
# 0   10.40000   10.400000   10.400000  ...       104.00        8           33
# 1   20.34495   20.937952   20.643731  ...   1368169.21       72           62
# 2  140.00000   20.937952   20.643731  ...     80211.00      207           64
# 3   78.00000   78.000000   78.000000  ...     78000.00      166           65
# 4   13.65000   14.050000   13.870000  ...  17412181.44       26           66
# 5   24.70000   25.500000   25.500000  ...   8478833.94      238           68
# 6   32.00000   34.000000   32.000000  ...     10829.90      258           69
# 7   21.42000   22.170000   21.750000  ...   6239458.10        2           71
# 8    7.65000    7.950000    7.940000  ...  13152230.45       84           73
# 9   15.41000   15.890000   15.700000  ...   2858224.49      164           74
#
# [10 rows x 8 columns]

# %%
from sklearn.model_selection import KFold, cross_val_score, train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, shuffle=True)

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)
# Out:
# [11:04:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
_ = plot_importance(reg, height=0.9)

# %%
xgb_pred = reg.predict(X_test)

# %%
r_sq2 = reg.score(X_test,y_test)

print('coefficient of determination:', r_sq2)
# Out:
# coefficient of determination: 0.9932061483885987

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':xgb_pred})
df
# Out:
#            Actual  Predicted
# 3789     2.760000   2.799814
# 114630  21.190000  21.221312
# 77065    4.860000   4.871630
# 99713   31.880000  31.656746
# 14663    1.190000   1.251910
# ...           ...        ...
# 128247  55.040000  56.390423
# 132986  18.080000  18.055593
# 95910   20.669128  21.185186
# 50406   32.790000  32.865299
# 65508    2.820000   2.799814
#
# [30889 rows x 2 columns]

# %%
act_pred=df.plot('Actual', 'Predicted', kind='scatter')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
rmse = sqrt(mean_squared_error(y_test,xgb_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1.673
